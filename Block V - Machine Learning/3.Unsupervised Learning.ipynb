# %% [markdown]
# ## 3. Unsupervised Learning

# %% [markdown]
# ### 3.1. Clustering for Dataset Exploration

# %% [markdown]
# ### 3.2. Visualization with Hierarchical Clustering and t-SNE

# %% [markdown]
# ### 3.3. Decorrelating Your Data and Dimension Reduction

# %% [markdown]
# ### 3.4. Discovering Interpretable Features
